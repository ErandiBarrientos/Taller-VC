# %% [markdown]
# <a href="https://colab.research.google.com/github/ErandiBarrientos/Taller-VC/blob/main/Ejercicios_Clase_VC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Materia: Vision por Computadora

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


img = cv2.imread('Fig0221.tif', 0)

# %whos

print('Dimensiones : ',img.shape)
print (img)

plt.imshow(img) #despliega por default RGB
plt.title('Imagen en RGB')
plt.show()

plt.imshow(img,cmap='gray')
plt.title('Imagen en Escala de Grises')
plt.show()
# Out:
# Variable   Type       Data/Info
# -------------------------------
# cv2        module     <module 'cv2.cv2' from '/<...>37m-x86_64-linux-gnu.so'>
# files      module     <module 'google.colab.fil<...>s/google/colab/files.py'>
# fn         str        Fig0221.tif
# img        ndarray    452x374: 169048 elems, type `uint8`, 169048 bytes (165.0859375 kb)
# np         module     <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# uploaded   dict       n=1
# Dimensiones :  (452, 374)
# [[ 52  52  52 ...  52  50  52]
#  [ 52  52  52 ...  52  50  52]
#  [ 52  52  52 ...  52  50  50]
#  ...
#  [ 79  79  79 ...  97 112 131]
#  [ 79  81  79 ... 113 122 132]
#  [ 79  81  81 ... 131 129 127]]
