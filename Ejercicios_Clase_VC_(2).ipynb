# %% [markdown]
# <a href="https://colab.research.google.com/github/ErandiBarrientos/Taller-VC/blob/main/Ejercicios_Clase_VC_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CAPITULO # 2**

# %% [markdown]
# **Diapositiva 22**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


img = cv2.imread('Fig0221.tif',-1)

# %whos

print ('Dimensiones : ',img.shape)
#print (img)

img2=cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

print ('Dimensiones : ',img2.shape)
#print (img_gray)

cv2.imshow('Imagen en Color',img2)
cv2.imshow('Imagen en escala de Grises',img)

#plt.imshow(img) #despliega por default BGR
#plt.title('Imagen en BGR')
#plt.show()

#plt.imshow(img_gray)
#plt.title('Imagen en Escala de Grises')
#plt.show()
# Out:
# Variable    Type       Data/Info
# --------------------------------
# cv2         module     <module 'cv2.cv2' from '/<...>37m-x86_64-linux-gnu.so'>
# img         ndarray    452x374: 169048 elems, type `uint8`, 169048 bytes (165.0859375 kb)
# img_color   ndarray    452x374: 169048 elems, type `uint8`, 169048 bytes (165.0859375 kb)
# img_gray    ndarray    452x374x3: 507144 elems, type `uint8`, 507144 bytes (495.2578125 kb)
# np          module     <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# plt         module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# Dimensiones :  (452, 374)
# Dimensiones :  (452, 374, 3)
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-17-76aebcf1e727> in <module>()
#      16 #print (img_gray)
#      17
# ---> 18 cv2.imshow('Imagen en Color',img2)
#      19 cv2.imshow('Imagen en escala de Grises',img)
#      20
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# Diapositiva 30

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

img = cv2.imread('Fig0221.tif', 0)

print ('Valor del Pixel:',img[25][50])

line = img[226,:]

#graficar linea
plt.plot(line)
plt.show()

#crear rejilla o mesh
xx, yy = np.mgrid[0:img.shape[0], 0:img.shape[1]]

#crear grafico de superficie
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(xx, yy, img ,rstride=1, cstride=1,linewidth=0)
plt.show()

#crear gráfico de contornos
fig = plt.figure()
plt.contour (xx, yy, img)
plt.show()
# Out:
# Valor del Pixel: 52

# %% [markdown]
# **Diapositiva 55**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Fig0219.tif', 0)

scale_percent = 2
width = int(img.shape[0]* scale_percent / 100)
height = int(img.shape[1]* scale_percent / 100)
dim = (width, height)

img_SCALED = cv2.resize(img,dim,interpolation=cv2.INTER_LINEAR)

plt.imshow(img, cmap='gray')
plt.title('Imagen Original')
plt.show()

plt.imshow(img_SCALED, cmap='gray')
plt.title('Imagen Escalada')
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Fig0219.tif', 0)

dim128 = (128, 128)
dim64 = (64, 64)
dim32 = (32, 32)


scaled_LINEAR_128 = cv2.resize(img, dim128, interpolation=cv2.INTER_LINEAR)
scaled_LINEAR_64 = cv2.resize(img, dim64, interpolation=cv2.INTER_LINEAR)
scaled_LINEAR_32 = cv2.resize(img, dim32, interpolation=cv2.INTER_LINEAR)

scaled_NEAREST_128 = cv2.resize(img, dim128, interpolation=cv2.INTER_NEAREST)
scaled_NEAREST_64 = cv2.resize(img, dim64, interpolation=cv2.INTER_NEAREST)
scaled_NEAREST_32 = cv2.resize(img, dim32, interpolation=cv2.INTER_NEAREST)

plt.subplot(2,3,1),plt.imshow(scaled_LINEAR_128, cmap='gray'), plt.title('a')
plt.xticks([]), plt.yticks([])
plt.subplot(2,3,2),plt.imshow(scaled_LINEAR_64, cmap='gray'), plt.title('b')
plt.xticks([]), plt.yticks([])
plt.subplot(2,3,3),plt.imshow(scaled_LINEAR_32, cmap='gray'), plt.title('c')
plt.xticks([]), plt.yticks([])
plt.subplot(2,3,4),plt.imshow(scaled_NEAREST_128, cmap='gray'), plt.title('d')
plt.xticks([]), plt.yticks([])
plt.subplot(2,3,5),plt.imshow(scaled_NEAREST_64, cmap='gray'), plt.title('e')
plt.xticks([]), plt.yticks([])
plt.subplot(2,3,6),plt.imshow(scaled_NEAREST_32, cmap='gray'), plt.title('f')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

# Cargamos la imagen del disco duro
imagen = cv2.imread("BW01.png",0)
[umbral, etiquetas] = cv2.threshold(imagen,127,255,cv2.THRESH_BINARY)
BW=cv2.connectedComponents(imagen,etiquetas,connectivity=8,ltype=cv2.CV_16U)
plt.imshow(BW[1])
plt.colorbar()
plt.show()
plt.imshow(BW[1], cmap='gray') 
plt.show()
